# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
import seaborn as sns

# %%
df = pd.read_csv (r'./World_Wide_Unicorn_Startups.csv')
print(df.shape)
df.head()
# Out:
# (936, 10)
#      Company  Valuation        Date        Country           City  \
# 0  Bytedance      140.0    4/7/2017          China        Beijing
# 1     SpaceX      100.3   12/1/2012  United States      Hawthorne
# 2     Stripe       95.0   1/23/2014  United States  San Francisco
# 3     Klarna       45.6  12/12/2011         Sweden      Stockholm
# 4      Canva       40.0    1/8/2018      Australia    Surry Hills
#
#                        Industry  \
# 0       Artificial intelligence
# 1                         Other
# 2                       Fintech
# 3                       Fintech
# 4  Internet software & services
#
#                                            Investors  year  month  day
# 0  0      Sequoia Capital China, SIG Asia Investm...  2017      7    4
# 1  0      Sequoia Capital China, SIG Asia Investm...  2012      1   12
# 2  0      Sequoia Capital China, SIG Asia Investm...  2014     23    1
# 3  0      Sequoia Capital China, SIG Asia Investm...  2011     12   12
# ...

# %%
df.Industry.unique()
# Out:
# array(['Artificial intelligence', 'Other', 'Fintech',
#        'Internet software & services',
#        'Supply chain, logistics, & delivery',
#        'Data management & analytics', 'Edtech',
#        'E-commerce & direct-to-consumer', 'Hardware', 'Health',
#        'Consumer & retail', 'Auto & transportation', 'Finttech',
#        'Cybersecurity', 'Mobile & telecommunications', 'Travel',
#        'Artificial Intelligence'], dtype=object)

# %%
len(df.Country.unique())
# Out:
# 47

# %%
df_us=df.loc[df['Country']=='United States']

# %%
df.loc[df['Country']=='China']
# Out:
#                Company  Valuation        Date Country      City  \
# 0            Bytedance      140.0    4/7/2017   China   Beijing
# 13         Xiaohongshu       20.0   3/31/2016   China  Shanghai
# 16           Yuanfudao       15.5   5/31/2017   China   Beijing
# 17     DJI Innovations       15.0   1/23/2015   China  Shenzhen
# 18               SHEIN       15.0    7/3/2018   China  Shenzhen
# ..                 ...        ...         ...     ...       ...
# 895    Keenon Robotics        1.0   9/15/2021   China  Shanghai
# 896             HAYDON        1.0   9/24/2021   China  Shanghai
# 911               Moka        1.0   11/2/2021   China   Beijing
# 912             Tezign        1.0   11/2/2021   China  Shanghai
# 919  Gaussian Robotics        1.0  11/10/2021   China  Shanghai
#
#                                 Industry  \
# 0                Artificial intelligence
# 13       E-commerce & direct-to-consumer
# 16                                Edtech
# ...

# %%
df_us.loc[df['Industry']=='Hardware']
# Out:
#               Company  Valuation        Date        Country           City  \
# 84   Samsara Networks       6.30   3/22/2018  United States  San Francisco
# 171  Cerebras Systems       4.00  11/14/2018  United States      Los Altos
# 219        PsiQuantum       3.15   7/27/2021  United States      Palo Alto
# 303            Carbon       2.40   8/20/2015  United States   Redwood City
# 358          Formlabs       2.00    8/1/2018  United States     Somerville
# 401        Magic Leap       2.00  10/21/2014  United States     Plantation
# 428         Opentrons       1.80   9/23/2021  United States       New York
# 458         Infinidat       1.60   4/29/2015  United States        Waltham
# 701           Density       1.05  11/10/2021  United States  San Francisco
# 804    Locus Robotics       1.00   2/17/2021  United States     Wilmington
#
#      Industry                                          Investors  year  month  \
# ...

# %%
fig, ax = plt.subplots()

colors = {'B':'green', 'M':'red'}


ax.scatter(df['year'], df['Valuation'])
plt.xlabel('Year')
plt.ylabel('Valuation')
plt.show()

# %%
plt.scatter(x=df['year'], y=df['Country'], s=df['Valuation'])
#plt.margins(.4)
plt.show()
